# %% [markdown]
# <a href="https://colab.research.google.com/github/Vivek-Hiremath55/AI_Systems_Pro/blob/main/VivekHiremath/Playground_VivekHiremath.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 1 and 2 Combined
# ### Importing libraries and dataset

# %%
import pandas as pd, matplotlib.pyplot as plt, numpy as np
import h5py
from PIL import Image
import io
from IPython.display import display

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
train_meta_df = pd.read_csv(r'C:\Users\sared\Downloads\train-metadata.csv')
# Out:
# C:\Users\sared\AppData\Local\Temp\ipykernel_23356\168733388.py:1: DtypeWarning: Columns (51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_meta_df = pd.read_csv(r'C:\Users\sared\Downloads\train-metadata.csv')

# %%
train_meta_df.head()
# Out:
#         isic_id  target  patient_id  age_approx   sex anatom_site_general  \
# 0  ISIC_0015670       0  IP_1235828        60.0  male     lower extremity
# 1  ISIC_0015845       0  IP_8170065        60.0  male           head/neck
# 2  ISIC_0015864       0  IP_6724798        60.0  male     posterior torso
# 3  ISIC_0015902       0  IP_4111386        65.0  male      anterior torso
# 4  ISIC_0024200       0  IP_8313778        55.0  male      anterior torso
#
#    clin_size_long_diam_mm          image_type tbp_tile_type   tbp_lv_A  ...  \
# 0                    3.04  TBP tile: close-up     3D: white  20.244422  ...
# 1                    1.10  TBP tile: close-up     3D: white  31.712570  ...
# 2                    3.40  TBP tile: close-up        3D: XP  22.575830  ...
# 3                    3.22  TBP tile: close-up        3D: XP  14.242329  ...
# 4                    2.73  TBP tile: close-up     3D: white  24.725520  ...
#
# ...

# %%
train_meta_df.shape
# Out:
# (401059, 55)

# %%
def null_percentage(df): # for null percentage 
    """
    Gives the percentage of missing values in a dataframe.
    Input : Dataframe
    Output : Top 10 columns with missing values
    """
    null_list = []

   
    for col in df.columns:
        pct_missing = df[col].isna().sum() * 100 / len(df)
        null_list.append(pct_missing)

    
    null_df = pd.DataFrame({'Column': df.columns, 'Null Percentage': null_list})

    
    null_df = null_df.sort_values(by='Null Percentage', ascending=False)

    return null_df.head(10)

# %%
null_percentage(train_meta_df)
# Out:
#                  Column  Null Percentage
# 51               iddx_5        99.999751
# 52    mel_mitotic_index        99.986785
# 53         mel_thick_mm        99.984292
# 50               iddx_4        99.862614
# 49               iddx_3        99.734453
# 48               iddx_2        99.733705
# 45            lesion_id        94.500061
# 4                   sex         2.871647
# 5   anatom_site_general         1.435200
# 3            age_approx         0.697653

# %% [markdown]
# ### Images from hdf file

# %%
file_path = './train-image.hdf5'
hdf5_file = h5py.File(file_path, 'r')

# %%
name_list = list(hdf5_file.keys())

# %%
joblib.dump(name_list,"namelist.pkl")
# Out:
# ['namelist.pkl']

# %%
export_image_data_list = []

# %%
def display_image(image_data): # displaying and retriving the images only
    image = Image.open(io.BytesIO(image_data))
    display(image)

def image_selector(image_name): 
    image_data = hdf5_file[image_name][()]
    export_image_data_list.append(image_data)
    #display_image(image_data)

# %%
for i in range(len(name_list)-1):
    image_selector(name_list[i])

# %%
joblib.dump(export_image_data_list, 'image_data_list.pkl')
# Out:
# ['image_data_list.pkl']

# %% [markdown]
# #### Exploratory Data Analysis with respect to text data

# %%
df  = train_meta_df.copy()

# %%
null = null_percentage(df)

# %%
drop_list = []

for entry in null.index:
  if null['Null Percentage'][entry] > 50:
    drop_list.append(null['Column'][entry])

# %%
drop_list
# Out:
# ['iddx_5',
#  'mel_mitotic_index',
#  'mel_thick_mm',
#  'iddx_4',
#  'iddx_3',
#  'iddx_2',
#  'lesion_id']

# %%
df.drop(drop_list, axis=1, inplace=True)

# %%
df.shape
# Out:
# (401059, 48)

# %%
null_percentage(df)
# Out:
#                     Column  Null Percentage
# 4                      sex         2.871647
# 5      anatom_site_general         1.435200
# 3               age_approx         0.697653
# 0                  isic_id         0.000000
# 37          tbp_lv_stdLExt         0.000000
# 28         tbp_lv_location         0.000000
# 29  tbp_lv_location_simple         0.000000
# 30      tbp_lv_minorAxisMM         0.000000
# 31  tbp_lv_nevi_confidence         0.000000
# 32      tbp_lv_norm_border         0.000000

# %%
df.shape
# Out:
# (401059, 48)

# %%
df.dropna(axis = 0, inplace=True)
df.shape
# Out:
# (381914, 48)

# %%
null_percentage(df)
# Out:
#                     Column  Null Percentage
# 0                  isic_id              0.0
# 1                   target              0.0
# 26      tbp_lv_deltaLBnorm              0.0
# 27     tbp_lv_eccentricity              0.0
# 28         tbp_lv_location              0.0
# 29  tbp_lv_location_simple              0.0
# 30      tbp_lv_minorAxisMM              0.0
# 31  tbp_lv_nevi_confidence              0.0
# 32      tbp_lv_norm_border              0.0
# 33       tbp_lv_norm_color              0.0

# %%
df.head(2)
# Out:
#         isic_id  target  patient_id  age_approx   sex anatom_site_general  \
# 0  ISIC_0015670       0  IP_1235828        60.0  male     lower extremity
# 1  ISIC_0015845       0  IP_8170065        60.0  male           head/neck
#
#    clin_size_long_diam_mm          image_type tbp_tile_type   tbp_lv_A  ...  \
# 0                    3.04  TBP tile: close-up     3D: white  20.244422  ...
# 1                    1.10  TBP tile: close-up     3D: white  31.712570  ...
#
#    tbp_lv_symm_2axis  tbp_lv_symm_2axis_angle    tbp_lv_x     tbp_lv_y  \
# 0           0.590476                       85 -182.703552   613.493652
# 1           0.285714                       55   -0.078308  1575.687000
#
#     tbp_lv_z                             attribution  copyright_license  \
# 0 -42.427948  Memorial Sloan Kettering Cancer Center              CC-BY
# 1  57.174500  Memorial Sloan Kettering Cancer Center              CC-BY
#
#    iddx_full  iddx_1  tbp_lv_dnn_lesion_confidence
# ...

# %%
df.columns
# Out:
# Index(['isic_id', 'target', 'patient_id', 'age_approx', 'sex',
#        'anatom_site_general', 'clin_size_long_diam_mm', 'image_type',
#        'tbp_tile_type', 'tbp_lv_A', 'tbp_lv_Aext', 'tbp_lv_B', 'tbp_lv_Bext',
#        'tbp_lv_C', 'tbp_lv_Cext', 'tbp_lv_H', 'tbp_lv_Hext', 'tbp_lv_L',
#        'tbp_lv_Lext', 'tbp_lv_areaMM2', 'tbp_lv_area_perim_ratio',
#        'tbp_lv_color_std_mean', 'tbp_lv_deltaA', 'tbp_lv_deltaB',
#        'tbp_lv_deltaL', 'tbp_lv_deltaLB', 'tbp_lv_deltaLBnorm',
#        'tbp_lv_eccentricity', 'tbp_lv_location', 'tbp_lv_location_simple',
#        'tbp_lv_minorAxisMM', 'tbp_lv_nevi_confidence', 'tbp_lv_norm_border',
#        'tbp_lv_norm_color', 'tbp_lv_perimeterMM',
#        'tbp_lv_radial_color_std_max', 'tbp_lv_stdL', 'tbp_lv_stdLExt',
#        'tbp_lv_symm_2axis', 'tbp_lv_symm_2axis_angle', 'tbp_lv_x', 'tbp_lv_y',
#        'tbp_lv_z', 'attribution', 'copyright_license', 'iddx_full', 'iddx_1',
#        'tbp_lv_dnn_lesion_confidence'],
# ...

# %% [markdown]
# #### Selecting only columns which are related for desired output

# %%
columns_to_keep = ['target', 'age_approx', 'sex', 'anatom_site_general',
                   'clin_size_long_diam_mm', 'tbp_lv_areaMM2', 'tbp_lv_area_perim_ratio',
                   'tbp_lv_color_std_mean', 'tbp_lv_eccentricity', 'tbp_lv_location',
                    'tbp_lv_minorAxisMM','tbp_lv_perimeterMM', 'tbp_lv_x',
                   'tbp_lv_y', 'tbp_lv_z']

# %%
df_2 = df[columns_to_keep]

# %%
df_2.head(1)
# Out:
#    target  age_approx   sex anatom_site_general  clin_size_long_diam_mm  \
# 0       0        60.0  male     lower extremity                    3.04
#
#    tbp_lv_areaMM2  tbp_lv_area_perim_ratio  tbp_lv_color_std_mean  \
# 0        3.152561                 27.47617                    0.0
#
#    tbp_lv_eccentricity    tbp_lv_location  tbp_lv_minorAxisMM  \
# 0             0.901302  Right Leg - Upper            1.543016
#
#    tbp_lv_perimeterMM    tbp_lv_x    tbp_lv_y   tbp_lv_z
# 0            9.307003 -182.703552  613.493652 -42.427948

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler

# %%
df_2.drop('target', axis=1, inplace=True)
# Out:
# C:\Users\sared\AppData\Local\Temp\ipykernel_23356\2860293327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.drop('target', axis=1, inplace=True)

# %%
df_3 = pd.get_dummies(df_2, drop_first=True)

# %%
df_3.head(1)
#df_3.drop('target', axis = 1, inplace=True)
# Out:
#    age_approx  clin_size_long_diam_mm  tbp_lv_areaMM2  \
# 0        60.0                    3.04        3.152561
#
#    tbp_lv_area_perim_ratio  tbp_lv_color_std_mean  tbp_lv_eccentricity  \
# 0                 27.47617                    0.0             0.901302
#
#    tbp_lv_minorAxisMM  tbp_lv_perimeterMM    tbp_lv_x    tbp_lv_y  ...  \
# 0            1.543016            9.307003 -182.703552  613.493652  ...
#
#    tbp_lv_location_Right Leg  tbp_lv_location_Right Leg - Lower  \
# 0                      False                              False
#
#    tbp_lv_location_Right Leg - Upper  tbp_lv_location_Torso Back  \
# 0                               True                       False
#
#    tbp_lv_location_Torso Back Bottom Third  \
# 0                                    False
#
#    tbp_lv_location_Torso Back Middle Third  \
# 0                                    False
#
#    tbp_lv_location_Torso Back Top Third  tbp_lv_location_Torso Front  \
# ...

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_3)

# %%
vif_data = pd.DataFrame()
vif_data["Feature"] = df_3.columns
vif_data["VIF"] = [variance_inflation_factor(df_scaled, i) for i in range(df_scaled.shape[1])]
# Out:
# C:\Users\sared\anaconda3\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)

# %%
vif_data.sort_values(by="VIF", ascending=False)
# Out:
#                                     Feature        VIF
# 17         tbp_lv_location_Left Arm - Lower        inf
# 26        tbp_lv_location_Right Leg - Lower        inf
# 20         tbp_lv_location_Left Leg - Lower        inf
# 21         tbp_lv_location_Left Leg - Upper        inf
# 22                tbp_lv_location_Right Arm        inf
# 23        tbp_lv_location_Right Arm - Lower        inf
# 24        tbp_lv_location_Right Arm - Upper        inf
# 25                tbp_lv_location_Right Leg        inf
# 27        tbp_lv_location_Right Leg - Upper        inf
# 18         tbp_lv_location_Left Arm - Upper        inf
# 28               tbp_lv_location_Torso Back        inf
# 29  tbp_lv_location_Torso Back Bottom Third        inf
# 30  tbp_lv_location_Torso Back Middle Third        inf
# 31     tbp_lv_location_Torso Back Top Third        inf
# 32              tbp_lv_location_Torso Front        inf
# 33  tbp_lv_location_Torso Front Bottom Half        inf
# ...

# %% [markdown]
# ##### Checking for VIF and deleting colums which are not related to the output

# %%
df_2.drop('anatom_site_general', axis=1, inplace=True)
# Out:
# C:\Users\sared\AppData\Local\Temp\ipykernel_23356\271634559.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.drop('anatom_site_general', axis=1, inplace=True)

# %%
df_3 = pd.get_dummies(df_2, drop_first=True)

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_3)

vif_data = pd.DataFrame()
vif_data["Feature"] = df_3.columns
vif_data["VIF"] = [variance_inflation_factor(df_scaled, i) for i in range(df_scaled.shape[1])]

vif_data.sort_values(by="VIF", ascending=False)
# Out:
#                                     Feature        VIF
# 7                        tbp_lv_perimeterMM  85.503558
# 1                    clin_size_long_diam_mm  30.597818
# 6                        tbp_lv_minorAxisMM  27.937831
# 2                            tbp_lv_areaMM2  13.526980
# 16         tbp_lv_location_Left Leg - Lower  10.037970
# 9                                  tbp_lv_y  10.016436
# 22        tbp_lv_location_Right Leg - Lower   9.351317
# 27     tbp_lv_location_Torso Back Top Third   7.156831
# 26  tbp_lv_location_Torso Back Middle Third   6.360707
# 17         tbp_lv_location_Left Leg - Upper   5.902921
# 3                   tbp_lv_area_perim_ratio   5.891661
# 30     tbp_lv_location_Torso Front Top Half   5.808936
# 23        tbp_lv_location_Right Leg - Upper   5.736454
# 29  tbp_lv_location_Torso Front Bottom Half   3.855493
# 5                       tbp_lv_eccentricity   3.751050
# 20        tbp_lv_location_Right Arm - Upper   3.439145
# ...

# %%
df_2.drop('tbp_lv_perimeterMM', axis=1, inplace=True)
# Out:
# C:\Users\sared\AppData\Local\Temp\ipykernel_23356\4256033608.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.drop('tbp_lv_perimeterMM', axis=1, inplace=True)

# %%
df_3 = pd.get_dummies(df_2, drop_first=True)

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_3)

vif_data = pd.DataFrame()
vif_data["Feature"] = df_3.columns
vif_data["VIF"] = [variance_inflation_factor(df_scaled, i) for i in range(df_scaled.shape[1])]

vif_data.sort_values(by="VIF", ascending=False)
# Out:
#                                     Feature        VIF
# 6                        tbp_lv_minorAxisMM  17.442582
# 1                    clin_size_long_diam_mm  15.561106
# 2                            tbp_lv_areaMM2  11.363848
# 15         tbp_lv_location_Left Leg - Lower  10.035972
# 8                                  tbp_lv_y  10.015748
# 21        tbp_lv_location_Right Leg - Lower   9.349742
# 26     tbp_lv_location_Torso Back Top Third   7.152385
# 25  tbp_lv_location_Torso Back Middle Third   6.359125
# 16         tbp_lv_location_Left Leg - Upper   5.901079
# 29     tbp_lv_location_Torso Front Top Half   5.806196
# 22        tbp_lv_location_Right Leg - Upper   5.734830
# 28  tbp_lv_location_Torso Front Bottom Half   3.852279
# 5                       tbp_lv_eccentricity   3.721339
# 19        tbp_lv_location_Right Arm - Upper   3.438150
# 13         tbp_lv_location_Left Arm - Upper   3.399440
# 7                                  tbp_lv_x   2.777617
# ...

# %%
df_2.drop('tbp_lv_minorAxisMM', axis=1, inplace=True)
# Out:
# C:\Users\sared\AppData\Local\Temp\ipykernel_23356\2961118788.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.drop('tbp_lv_minorAxisMM', axis=1, inplace=True)

# %%
df_3 = pd.get_dummies(df_2, drop_first=True)

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_3)

vif_data = pd.DataFrame()
vif_data["Feature"] = df_3.columns
vif_data["VIF"] = [variance_inflation_factor(df_scaled, i) for i in range(df_scaled.shape[1])]

vif_data.sort_values(by="VIF", ascending=False)
# Out:
#                                     Feature        VIF
# 1                    clin_size_long_diam_mm  11.697564
# 14         tbp_lv_location_Left Leg - Lower  10.035501
# 7                                  tbp_lv_y  10.015726
# 20        tbp_lv_location_Right Leg - Lower   9.349273
# 2                            tbp_lv_areaMM2   8.477364
# 25     tbp_lv_location_Torso Back Top Third   7.151386
# 24  tbp_lv_location_Torso Back Middle Third   6.358573
# 15         tbp_lv_location_Left Leg - Upper   5.901079
# 28     tbp_lv_location_Torso Front Top Half   5.805892
# 21        tbp_lv_location_Right Leg - Upper   5.734830
# 27  tbp_lv_location_Torso Front Bottom Half   3.852267
# 18        tbp_lv_location_Right Arm - Upper   3.437972
# 12         tbp_lv_location_Left Arm - Upper   3.399260
# 6                                  tbp_lv_x   2.777617
# 11         tbp_lv_location_Left Arm - Lower   2.618812
# 17        tbp_lv_location_Right Arm - Lower   2.443906
# ...

# %%
df_2.drop('tbp_lv_areaMM2', axis=1, inplace=True)
# Out:
# C:\Users\sared\AppData\Local\Temp\ipykernel_23356\1804515885.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.drop('tbp_lv_areaMM2', axis=1, inplace=True)

# %%
df_3 = pd.get_dummies(df_2, drop_first=True)

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_3)

vif_data = pd.DataFrame()
vif_data["Feature"] = df_3.columns
vif_data["VIF"] = [variance_inflation_factor(df_scaled, i) for i in range(df_scaled.shape[1])]

vif_data.sort_values(by="VIF", ascending=False)
# Out:
#                                     Feature        VIF
# 13         tbp_lv_location_Left Leg - Lower  10.033366
# 6                                  tbp_lv_y  10.011265
# 19        tbp_lv_location_Right Leg - Lower   9.347173
# 24     tbp_lv_location_Torso Back Top Third   7.151383
# 23  tbp_lv_location_Torso Back Middle Third   6.357602
# 14         tbp_lv_location_Left Leg - Upper   5.900561
# 27     tbp_lv_location_Torso Front Top Half   5.805714
# 20        tbp_lv_location_Right Leg - Upper   5.734290
# 26  tbp_lv_location_Torso Front Bottom Half   3.852247
# 17        tbp_lv_location_Right Arm - Upper   3.437971
# 11         tbp_lv_location_Left Arm - Upper   3.399225
# 5                                  tbp_lv_x   2.777594
# 10         tbp_lv_location_Left Arm - Lower   2.618798
# 16        tbp_lv_location_Right Arm - Lower   2.443893
# 7                                  tbp_lv_z   2.065345
# 1                    clin_size_long_diam_mm   2.051162
# ...

# %%
# df_3 Is now a train set


X = df_3
y = df['target']


print(X.shape, y.shape)
# Out:
# (381914, 28) (381914,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=42, stratify=y)

# %%
y.value_counts()
# Out:
# target
# 0    381533
# 1       381
# Name: count, dtype: int64

# %%
# Combined dataset -> 

df_4 = pd.concat([df_3, df['target']], axis = 1)

# %%
target_pos = df_4[df_4['target'] == 1]

target_pos.shape
# Out:
# (381, 29)

# %%
target_neg_prep = df_4[df_4['target'] == 0]

# %%
target_neg = target_neg_prep.sample(n = 381)

# %%
equal_df = pd.concat([target_pos, target_neg], axis = 0)

# %%
X_e = equal_df.drop('target', axis = 1)
y_e = equal_df['target']

# %%
X_e_train, X_e_test, y_e_train, y_e_test = train_test_split(X_e, y_e, test_size = 0.2, random_state = 42, stratify = y_e)

# %% [markdown]
# #### Models:
# ##### 1. Logistic Regression
# ##### 2. Decision Tree
# ##### 3. Random Forest
# ##### 4. XGBoost Classifier

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from xgboost import XGBClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold

# %%
# Logistic Regression Parameter

lr_model= LogisticRegression()

# %%
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear', 'saga', 'newton-cg', 'lbfgs'],
    'max_iter': [100, 200, 300, 500, 1000]
}

# %%
grid_lr = GridSearchCV(lr_model, param_grid, cv=StratifiedKFold(10), scoring='f1', n_jobs = -1)

# %% [markdown]
# ### Trying to run it on test set cause train set is too big (taking too long)

# %%
grid_lr.fit(X_e_train, y_e_train)
# Out:
# C:\Users\sared\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 600 fits failed out of a total of 2400.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 300 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sared\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sared\anaconda3\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
best_lr_model = grid_lr.best_estimator_

# %%
y_pred_lr = best_lr_model.predict(X_e_test)

# %%
# Confusion Matrix

confusion_matrix_lr = confusion_matrix(y_e_test, y_pred_lr)

# %%
confusion_matrix_lr
# Out:
# array([[54, 23],
#        [30, 46]], dtype=int64)

# %%
TP_lr = confusion_matrix_lr[0][0]
FP_lr = confusion_matrix_lr[1][0]
FN_lr = confusion_matrix_lr[0][1]
TN_lr = confusion_matrix_lr[1][1]

# %%
# Metrics

sensitivity_lr = TP_lr / (TP_lr + FN_lr)

specificity_lr = TN_lr / (TN_lr + FP_lr)

sensitivity_lr, specificity_lr
# Out:
# (0.7012987012987013, 0.6052631578947368)

# %%
# Decison Tree

dt_model = DecisionTreeClassifier()

# %%
param_grid_dt = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 10, 20, 30, 40],
    'min_samples_split': [2, 5, 10, 15, 20],
    'min_samples_leaf': [1, 2, 4, 6, 8],
    'max_features': ['auto', 'sqrt', 'log2', None],
    'class_weight': ['balanced', None],
}

# %%
grid_dt = GridSearchCV(dt_model, param_grid_dt, cv=StratifiedKFold(10), scoring='f1', n_jobs = -1)

# %%
grid_dt.fit(X_e_train, y_e_train)
# Out:
# C:\Users\sared\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 5000 fits failed out of a total of 20000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2170 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sared\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sared\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\sared\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
best_dt_model = grid_dt.best_estimator_

# %%
y_pred_dt = best_dt_model.predict(X_e_test)

# Confusion Matrix

confusion_matrix_dt = confusion_matrix(y_e_test, y_pred_dt)

TP_dt = confusion_matrix_dt[0][0]
FP_dt = confusion_matrix_dt[1][0]
FN_dt = confusion_matrix_dt[0][1]
TN_dt = confusion_matrix_dt[1][1]

# %%
# Metrics

sensitivity_dt = TP_dt / (TP_dt + FN_dt)

specificity_dt = TN_dt / (TN_dt + FP_dt)

sensitivity_dt, specificity_dt
# Out:
# (0.7792207792207793, 0.6842105263157895)

# %%
# Random Forest

# %%
rf_model = RandomForestClassifier()

# %%
param_grid_rf= {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10, 15, 20],
    'min_samples_leaf': [1, 2, 4, 6, 8],
    'criterion': ['gini', 'entropy']
}

# %%
grid_rf = GridSearchCV(rf_model, param_grid_rf, cv=StratifiedKFold(10), scoring='f1', n_jobs = -1)

# %%
grid_rf.fit(X_e_train, y_e_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=None, shuffle=False),
#              estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20],
#                          'min_samples_leaf': [1, 2, 4, 6, 8],
#                          'min_samples_split': [2, 5, 10, 15, 20],
#                          'n_estimators': [100, 200, 300]},
#              scoring='f1')

# %%
best_rf_model = grid_rf.best_estimator_

# %%
y_pred_rf = best_rf_model.predict(X_e_test)

# Confusion Matrix

confusion_matrix_rf = confusion_matrix(y_e_test, y_pred_rf)

TP_rf = confusion_matrix_rf[0][0]
FP_rf = confusion_matrix_rf[1][0]
FN_rf = confusion_matrix_rf[0][1]
TN_rf = confusion_matrix_rf[1][1]

# %%
# Metrics

sensitivity_rf = TP_rf / (TP_rf + FN_rf)

specificity_rf = TN_rf / (TN_rf + FP_rf)

sensitivity_rf, specificity_rf
# Out:
# (0.8571428571428571, 0.8421052631578947)

# %%
import joblib

# %%
joblib.dump(best_rf_model,"rf_800model.pkl")
# Out:
# ['rf_800model.pkl']

# %%
joblib.dump(best_xgb_model,"xgb_800model.pkl")
# Out:
# ['xgb_800model.pkl']

# %%
joblib.dump(best_dt_model,"dt_800model.pkl")
# Out:
# ['dt_800model.pkl']

# %%
joblib.dump(best_lr_model,"lr_800model.pkl")
# Out:
# ['lr_800model.pkl']

# %%
# XGBoost

model_xgb = XGBClassifier()

# %%
param_grid_xgb = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 4, 5],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0],
    'gamma': [0, 0.1, 0.2],
    'min_child_weight': [1, 3, 5],
    'reg_alpha': [0, 0.1, 0.2],
    'reg_lambda': [0, 0.1, 0.2]
}

# %%
grid_xgb = GridSearchCV(model_xgb, param_grid, cv=StratifiedKFold(10), scoring='f1', n_jobs = -1)

# %%
grid_xgb.fit(X_test, y_test)
# Out:
# C:\Users\sared\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [16:41:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "C", "max_iter", "penalty", "solver" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=None, shuffle=False),
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
# ...

# %%
best_xgb_model = grid_xgb.best_estimator_

# %%
y_pred_xgb = best_xgb_model.predict(X_e_test)

# Confusion Matrix

confusion_matrix_xgb = confusion_matrix(y_e_test, y_pred_xgb)

TP_xgb = confusion_matrix_xgb[0][0]
FP_xgb = confusion_matrix_xgb[1][0]
FN_xgb = confusion_matrix_xgb[0][1]
TN_xgb = confusion_matrix_xgb[1][1]

# %%
# Metrics

sensitivity_xgb = TP_xgb / (TP_xgb + FN_xgb)

specificity_xgb = TN_xgb / (TN_xgb + FP_xgb)

sensitivity_xgb, specificity_xgb
# Out:
# (1.0, 0.07894736842105263)

# %%
confusion_matrix_xgb
# Out:
# array([[77,  0],
#        [70,  6]], dtype=int64)

# %%
test_meta_df = pd.read_csv(r'C:\Users\sared\Downloads\test-metadata.csv')

# %%
cols_needed = df_3.columns

# %%
drop_list_2 = []

# %%
for col in test_meta_df.columns:
    if col not in cols_needed:
        drop_list_2.append(col)

drop_list_2
# Out:
# ['isic_id',
#  'patient_id',
#  'sex',
#  'anatom_site_general',
#  'image_type',
#  'tbp_tile_type',
#  'tbp_lv_A',
#  'tbp_lv_Aext',
#  'tbp_lv_B',
#  'tbp_lv_Bext',
#  'tbp_lv_C',
#  'tbp_lv_Cext',
#  'tbp_lv_H',
#  'tbp_lv_Hext',
#  'tbp_lv_L',
#  'tbp_lv_Lext',
#  'tbp_lv_areaMM2',
#  'tbp_lv_deltaA',
#  'tbp_lv_deltaB',
#  'tbp_lv_deltaL',
#  'tbp_lv_deltaLB',
#  'tbp_lv_deltaLBnorm',
#  'tbp_lv_location',
#  'tbp_lv_location_simple',
#  'tbp_lv_minorAxisMM',
#  'tbp_lv_nevi_confidence',
#  'tbp_lv_norm_border',
#  'tbp_lv_norm_color',
#  'tbp_lv_perimeterMM',
#  'tbp_lv_radial_color_std_max',
#  'tbp_lv_stdL',
#  'tbp_lv_stdLExt',
#  'tbp_lv_symm_2axis',
#  'tbp_lv_symm_2axis_angle',
#  'attribution',
#  'copyright_license']

# %%
df_t = test_meta_df.copy()

# %%
df_t.drop(columns = drop_list_2, axis = 1, inplace = True)

df_t.head()
# Out:
#    age_approx  clin_size_long_diam_mm  tbp_lv_area_perim_ratio  \
# 0        45.0                    2.70                22.907010
# 1        35.0                    2.52                18.957821
# 2        65.0                    3.16                19.464400
#
#    tbp_lv_color_std_mean  tbp_lv_eccentricity   tbp_lv_x     tbp_lv_y  \
# 0               0.461149             0.664465 -155.06510  1511.222000
# 1               0.000000             0.926698 -112.36924   629.535889
# 2               0.251236             0.894776  -84.29282  1303.978000
#
#      tbp_lv_z
# 0  113.980100
# 1  -15.019287
# 2  -28.576050

# %%
df_3.columns
# Out:
# Index(['age_approx', 'clin_size_long_diam_mm', 'tbp_lv_area_perim_ratio',
#        'tbp_lv_color_std_mean', 'tbp_lv_eccentricity', 'tbp_lv_x', 'tbp_lv_y',
#        'tbp_lv_z', 'sex_male', 'tbp_lv_location_Left Arm',
#        'tbp_lv_location_Left Arm - Lower', 'tbp_lv_location_Left Arm - Upper',
#        'tbp_lv_location_Left Leg', 'tbp_lv_location_Left Leg - Lower',
#        'tbp_lv_location_Left Leg - Upper', 'tbp_lv_location_Right Arm',
#        'tbp_lv_location_Right Arm - Lower',
#        'tbp_lv_location_Right Arm - Upper', 'tbp_lv_location_Right Leg',
#        'tbp_lv_location_Right Leg - Lower',
#        'tbp_lv_location_Right Leg - Upper', 'tbp_lv_location_Torso Back',
#        'tbp_lv_location_Torso Back Bottom Third',
#        'tbp_lv_location_Torso Back Middle Third',
#        'tbp_lv_location_Torso Back Top Third', 'tbp_lv_location_Torso Front',
#        'tbp_lv_location_Torso Front Bottom Half',
#        'tbp_lv_location_Torso Front Top Half'],
#       dtype='object')
